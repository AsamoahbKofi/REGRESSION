# %% [markdown]
# # Importing useful Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random as rn

from scipy import stats

seed = 42
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline

# %%
pd.set_option("display.max_columns",3754)
data=pd.read_csv("C:/Users/JUNIOR/Favorites/Links/new/jUPYTER/projjjjjjjjjject/Projects/visualizatio/ds_salaries.csv")
data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
def infos():
    print(data.info())
    print(80* "*")
    print("\n")
    print(data.describe())
    
    
infos()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB
# None
# ********************************************************************************
#
#
#          work_year        salary  salary_in_usd  remote_ratio
# ...

# %%
[cols.strip() for cols in data.columns]
data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
data["experience_level"].unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %%
data["experience_level"]=data["experience_level"].replace("SE","Senior")
data["experience_level"]=data["experience_level"].replace("MI","Intermediate Level")
data["experience_level"]=data["experience_level"].replace("EN","Entry Level")
data["experience_level"]=data["experience_level"].replace("EX","Executive Level")
data.head()
# Out:
#    work_year    experience_level employment_type                 job_title  \
# 0       2023              Senior              FT  Principal Data Scientist
# 1       2023  Intermediate Level              CT               ML Engineer
# 2       2023  Intermediate Level              CT               ML Engineer
# 3       2023              Senior              FT            Data Scientist
# 4       2023              Senior              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
data["employment_type"].unique()
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %%
data["employment_type"]=data["employment_type"].replace({
    "FT":"Full Time",
    "CT": "Contractor",
    "FL":"Freelancer",
    "PT":"Part Time",
})
data.head()
# Out:
#    work_year    experience_level employment_type                 job_title  \
# 0       2023              Senior       Full Time  Principal Data Scientist
# 1       2023  Intermediate Level      Contractor               ML Engineer
# 2       2023  Intermediate Level      Contractor               ML Engineer
# 3       2023              Senior       Full Time            Data Scientist
# 4       2023              Senior       Full Time            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
data["salary_currency"].unique()
# Out:
# array(['EUR', 'USD', 'INR', 'HKD', 'CHF', 'GBP', 'AUD', 'SGD', 'CAD',
#        'ILS', 'BRL', 'THB', 'PLN', 'HUF', 'CZK', 'DKK', 'JPY', 'MXN',
#        'TRY', 'CLP'], dtype=object)

# %%
data["salary_currency"]=data["salary_currency"].replace({
    "EUR":"Europe Euros",
    "USD": "USA USD",
    "INR":"India Rupee",
    "HKD":"HongKong HongKDollar",
    "CHF":"Switzerland CHF",
    "GBP":"UK Pounds",
    "AUD":"Australia AusDollar",
    "SGD":"Singapore SingpDollar",
    "CAD":"Canada CanadianDollar",
    "ILS":"Israel ILS",
    "BRL":"Brazil BRL",
    "THB":"Thailand THB",
    "PLN":"Poland PLN",
    "HUF":"Hungary HUF",
    "CZK":"Czech CZK",
    "DKK":"Denmark DKK",
    "JPY":"Japan Yen",
    "MXN":"Mexico MXN",
    "TRY":"Turkey Lira",
    "CLP":"Chile CLP"
    
})
data["country"]=data["salary_currency"].apply(lambda x:x.split(" ")[0])
data.head()
# Out:
#    work_year    experience_level employment_type                 job_title  \
# 0       2023              Senior       Full Time  Principal Data Scientist
# 1       2023  Intermediate Level      Contractor               ML Engineer
# 2       2023  Intermediate Level      Contractor               ML Engineer
# 3       2023              Senior       Full Time            Data Scientist
# 4       2023              Senior       Full Time            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000    Europe Euros          85847                 ES           100
# 1   30000         USA USD          30000                 US           100
# 2   25500         USA USD          25500                 US           100
# 3  175000         USA USD         175000                 CA           100
# 4  120000         USA USD         120000                 CA           100
#
#   company_location company_size country
# ...

# %%
data["company_size"].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
data["company_size"]=data["company_size"].replace({
    "L":"Large",
    "S":"Small",
    "M":"Medium"
    
})
data.head()
# Out:
#    work_year    experience_level employment_type                 job_title  \
# 0       2023              Senior       Full Time  Principal Data Scientist
# 1       2023  Intermediate Level      Contractor               ML Engineer
# 2       2023  Intermediate Level      Contractor               ML Engineer
# 3       2023              Senior       Full Time            Data Scientist
# 4       2023              Senior       Full Time            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000    Europe Euros          85847                 ES           100
# 1   30000         USA USD          30000                 US           100
# 2   25500         USA USD          25500                 US           100
# 3  175000         USA USD         175000                 CA           100
# 4  120000         USA USD         120000                 CA           100
#
#   company_location company_size country
# ...

# %%
len(data[data["employee_residence"]!=data["company_location"]])
# Out:
# 96

# %%
len(data[data["employee_residence"]==data["company_location"]])
# Out:
# 3659

# %%
data[["employee_residence","company_location","country"]]
# Out:
#      employee_residence company_location country
# 0                    ES               ES  Europe
# 1                    US               US     USA
# 2                    US               US     USA
# 3                    CA               CA     USA
# 4                    CA               CA     USA
# ...                 ...              ...     ...
# 3750                 US               US     USA
# 3751                 US               US     USA
# 3752                 US               US     USA
# 3753                 US               US     USA
# 3754                 IN               IN   India
#
# [3755 rows x 3 columns]

# %%
def assign_broader_category(job_title):
    data_engineering = ["Data DevOps Engineer","Data Management Specialist","Data Analytics Consultant","Data Operations Analyst","Marketing Data Engineer","Azure Data Engineer","Data Infrastructure Engineer","Data Analytics Specialist","Data Operations Engineer","Financial Data Analyst","Marketing Data Analyst","Data Analytics Engineer","Product Data Analyst","Staff Data Analyst","Compliance Data Analyst","Data Quality Analyst","Data Strategist","Big Data Engineer","Finance Data Analyst","Data Modeler","Data Engineer", "Data Analyst", "Analytics Engineer", "BI Data Analyst", "Business Data Analyst", "BI Developer", "BI Analyst", "Business Intelligence Engineer", "BI Data Engineer", "Power BI Developer"]
    data_scientist = ["Product Data Scientist","Data Science Consultant","Applied Data Scientist","Data Scientist", "Applied Scientist", "Research Scientist", "3D Computer Vision Researcher", "Deep Learning Researcher", "AI/Computer Vision Engineer"]
    machine_learning = ["MLOps Engineer","Machine Learning Engineer", "ML Engineer", "Lead Machine Learning Engineer", "Principal Machine Learning Engineer"]
    data_architecture = ["Data Architect", "Big Data Architect", "Cloud Data Architect", "Principal Data Architect"]
    management = ["Data Science Manager", "Director of Data Science", "Head of Data Science", "Data Scientist Lead", "Head of Machine Learning", "Manager Data Management", "Data Analytics Manager","Data Specialist","Head of Data","Data Manager","Staff Data Scientist"]
    Artificail_intelligence=["Computer Vision Engineer","AI Scientist","Computer Vision Software Engineer","NLP Engineer"]
    
    
    if job_title in data_engineering:
        return "Data Engineering"
    elif job_title in data_scientist:
        return "Data Science"
    elif job_title in machine_learning:
        return "Machine Learning"
    elif job_title in data_architecture:
        return "Data Architecture"
    elif job_title in management:
        return "Management"
    elif "Principal" in job_title or "Lead" in job_title:
        return "Management"
    elif "Learning" in job_title:
        return "Machine Learning"
    elif "Research" in job_title:
        return "Research Engineer"
    elif "Cloud" in job_title:
        return "Cloud Engineering"
    elif job_title in Artificail_intelligence or "AI" in job_title:
        return "Artificail_intelligence"
    else:
        return "Other"

# Apply the function to the 'job_title' column and create a new column 'job_category'
data['grouped_job_category'] = data['job_title'].apply(assign_broader_category)

# %%
data["grouped_job_category"].value_counts()
# Out:
# Data Engineering           1882
# Data Science               1020
# Machine Learning            418
# Management                  203
# Data Architecture           105
# Artificail_intelligence      59
# Research Engineer            37
# Other                        23
# Cloud Engineering             8
# Name: grouped_job_category, dtype: int64

# %%
data["work_year"].unique()
# Out:
# array([2023, 2022, 2020, 2021], dtype=int64)

# %%
data1=data[data["work_year"]==2023]
data2=data[data["work_year"]==2022]
data3=data[data["work_year"]==2020]
data4=data[data["work_year"]==2021]

# %%
data.head()
# Out:
#    work_year    experience_level employment_type                 job_title  \
# 0       2023              Senior       Full Time  Principal Data Scientist
# 1       2023  Intermediate Level      Contractor               ML Engineer
# 2       2023  Intermediate Level      Contractor               ML Engineer
# 3       2023              Senior       Full Time            Data Scientist
# 4       2023              Senior       Full Time            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000    Europe Euros          85847                 ES           100
# 1   30000         USA USD          30000                 US           100
# 2   25500         USA USD          25500                 US           100
# 3  175000         USA USD         175000                 CA           100
# 4  120000         USA USD         120000                 CA           100
#
#   company_location company_size country grouped_job_category
# ...

# %% [markdown]
# # VISUALIZATION

# %%
cols=["work_year","experience_level","employment_type","grouped_job_category"]
for xx in cols:
    fig, ax  = plt.subplots(figsize = (10,5))
    ax = sns.countplot(x = xx, data = data, palette='mako_r', order = data[xx].value_counts().index)
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
    ax.bar_label(ax.containers[0])
    plt.title(f'Number of {xx}')
    plt.show()

# %%
cols=["work_year","experience_level","employment_type","grouped_job_category"]
for col in data[cols]:
    f,ax=plt.subplots(figsize=(20,8))
    sns.violinplot(x=col,y="salary_in_usd",data=data)

# %% [markdown]
# # Distribution of Salary

# %%
def num_plot(df, col, title, symb):
    fig, ax = plt.subplots(2, 1, sharex = True, figsize = (8,5),gridspec_kw = {"height_ratios": (.2, .8)})
    ax[0].set_title(title)
    sns.boxplot(x = col, data = df, ax = ax[0])
    ax[0].set(yticks = [])
    sns.histplot(x = col, data = df, ax = ax[1])
    ax[1].set_xlabel(col)
    plt.axvline(df[col].mean(), color = 'g', label = 'mean=' + str(np.round(df[col].mean(),1)) + symb)
    plt.axvline(df[col].median(), color = 'red', label = 'median='+ str(np.round(df[col].median(),1)) + symb)
    plt.axvline(df[col].mode()[0], color = 'purple', label = 'mode='+ str(df[col].mode()[0]) + symb)
    plt.legend(bbox_to_anchor = (1, 1.03), ncol = 1, fancybox = True, shadow = True, frameon = True)
    plt.tight_layout()
    plt.show()

# %%
num_plot(data, 'salary_in_usd', 'Salary Distribution','USD')

# %%
sns.displot(data["salary_in_usd"],kde=True)

# %%
import plotly.express as px
fig = px.box(data, y = 'salary_in_usd')
fig.show()
# Out:
# <div>                            <div id="600c7840-be7d-4ac8-9c68-351c3f6bbed3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("600c7840-be7d-4ac8-9c68-351c3f6bbed3")) {                    Plotly.newPlot(                        "600c7840-be7d-4ac8-9c68-351c3f6bbed3",                        [{"alignmentgroup":"True","hovertemplate":"salary_in_usd=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[85847,30000,25500,175000,120000,222200,136000,219000,141000,147100,90700,130000,100000,213660,130760,147100,90700,170000,150000,150000,110000,275000,174000,230000,143200,225000,156400,200000,130000,90000,72000,253200,90700,342810,184590,1
# ...

# %%
# apply formatting to describe method for 'adjusted_salary' column
formatted_data = data.loc[:, 'salary_in_usd'].describe().apply(lambda x: f'{x:.2f}')

# create boxplot and swarmplot for 'adjusted_salary' column
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['salary_in_usd'], palette='coolwarm')
sns.swarmplot(x=data['salary_in_usd'], color='blue', alpha=0.4, size=2.5)
plt.ylabel('Salary in USD')
plt.title('Boxplot and Swarmplot of Salary in USD')
plt.show()

# apply styling to formatted data
styled_data = formatted_data.to_frame().style \
    .background_gradient(cmap='Blues') \
    .set_properties(**{'text-align': 'center', 'border': '1px solid black'})

# display styled data
display(styled_data)
# Out:
# <style type="text/css">
# #T_92ec2_row0_col0, #T_92ec2_row1_col0, #T_92ec2_row2_col0, #T_92ec2_row3_col0, #T_92ec2_row4_col0, #T_92ec2_row5_col0, #T_92ec2_row6_col0, #T_92ec2_row7_col0 {
#   text-align: center;
#   border: 1px solid black;
# }
# </style>
# <table id="T_92ec2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92ec2_level0_col0" class="col_heading level0 col0" >salary_in_usd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92ec2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_92ec2_row0_col0" class="data row0 col0" >3755.00</td>
#     </tr>
#     <tr>
#       <th id="T_92ec2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_92ec2_row1_col0" class="data row1 col0" >137570.39</td>
#     </tr>
#     <tr>
#       <th id="T_92ec2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_92ec2_row2_col0" class="data row2 col0" >63055.63</td>
# ...

# %%
#  Median salary by job title
pivot_table = data.pivot_table(values='salary_in_usd', index='grouped_job_category', columns='work_year', aggfunc='median')
plt.figure(figsize=(14, 6))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Median Salary by Year')
plt.xlabel('Year')
plt.ylabel('Job Title')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import Lars
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.model_selection import cross_val_predict
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
linear=LinearRegression()
alpha = 1.0  # Regularization strength
ridge_model = Ridge(alpha=alpha)
alpha = 0.1  # Regularization strength
lasso_model = Lasso(alpha=alpha)
bayesian_ridge = BayesianRidge()
ard_regression = ARDRegression()
lars = Lars()
omp = OrthogonalMatchingPursuit(n_nonzero_coefs=5) 
passive_aggressive_regressor = PassiveAggressiveRegressor(C=1.0, max_iter=1000, random_state=42)
dt_regressor = DecisionTreeRegressor(random_state=0)
ran=RandomForestRegressor(n_estimators=20)
gradient=GradientBoostingRegressor(learning_rate=0.1,n_estimators=10)
hist=HistGradientBoostingRegressor(learning_rate=0.1,l2_regularization=0.1)
ada=AdaBoostRegressor(n_estimators=10,learning_rate=0.2,random_state=40)
knn=KNeighborsRegressor(n_neighbors=10)
el=ElasticNet(alpha=0.1)

# %%
num_col=["experience_level","employment_type","job_title",
         "salary_currency","employee_residence",
         "company_location","company_size","country","grouped_job_category"]
pd.get_dummies(data, columns = num_col, drop_first = True)
en=LabelEncoder()
for cols in num_col:
    data[cols]=en.fit_transform(data[cols])
#pd.set_option("display.max_columns",27)
data.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2023                 3                2         84   80000
# 1       2023                 2                0         66   30000
# 2       2023                 2                0         66   25500
# 3       2023                 3                2         47  175000
# 4       2023                 3                2         47  120000
#
#    salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0                6          85847                  26           100
# 1               19          30000                  75           100
# 2               19          25500                  75           100
# 3               19         175000                  11           100
# 4               19         120000                  11           100
#
#    company_location  company_size  country  grouped_job_category
# 0                25             0        6                     6
# ...

# %%
Q1 = np.percentile(data['salary_in_usd'], 25)
Q3 = np.percentile(data['salary_in_usd'], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
data = data[(data['salary_in_usd'] >= lower_bound) & (data['salary_in_usd'] <= upper_bound)]
data.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2023                 3                2         84   80000
# 1       2023                 2                0         66   30000
# 2       2023                 2                0         66   25500
# 3       2023                 3                2         47  175000
# 4       2023                 3                2         47  120000
#
#    salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0                6          85847                  26           100
# 1               19          30000                  75           100
# 2               19          25500                  75           100
# 3               19         175000                  11           100
# 4               19         120000                  11           100
#
#    company_location  company_size  country  grouped_job_category
# 0                25             0        6                     6
# ...

# %%
x=data.drop(["job_title","salary","salary_in_usd"],axis=1)
y=data["salary_in_usd"]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50,test_size=0.5)

standard=MinMaxScaler()
x_train_new=standard.fit_transform(x_train)
x_test_new=standard.transform(x_test)

# %%
def get_score(model):
    model.fit(x_train_new,y_train)
    pred=model.predict(x_test_new)
    score=model.score(x_test_new,y_test)
    return score*100

print("These are the accuracy scores for the Testing data  \n")
print(f' For Linear Regression Algorithm, we had an accuracy of {get_score(linear)}')
print(f' For  Ridge Algorithm, we had an accuracy of {get_score(ridge_model)}')
print(f' For Lasso Regression Algorithm, we had an accuracy of {get_score(lasso_model)}')
print(f' For Bayesian Algorithm, we had an accuracy of {get_score(bayesian_ridge)}')
print(f' For ARDRegression Algorithm, we had an accuracy of {get_score(ard_regression)}')
print(f' For Lars Algorithm, we had an accuracy of {get_score(lars)}')
print(f' For  Orthogonal Matching Pursuit Algorithm, we had an accuracy of {get_score(omp)}')
print(f' For Passive Aggression Regressor Algorithm, we had an accuracy of {get_score(passive_aggressive_regressor)}')
print(f' For Decision TreeRegressor Algorithm, we had an accuracy of {get_score(dt_regressor)}')
print(f' For Random Forest Regressor Algorithm, we had an accuracy of {get_score(ran)}')

print(f' For Gradient Boost Regressor Algorithm, we had an accuracy of {get_score(gradient)}')
print(f' For Hist Regressor Algorithm, we had an accuracy of {get_score(hist)}')
print(f' For Adaboost Forest Regressor Algorithm, we had an accuracy of {get_score(ada)}')
print(f' For KNN Regressor Algorithm, we had an accuracy of {get_score(knn)}')
print(f' For Elastic Net Algorithm, we had an accuracy of {get_score(el)}')
# Out:
# These are the accuracy scores for the Testing data
#
#  For Linear Regression Algorithm, we had an accuracy of 31.88254087881316
#  For  Ridge Algorithm, we had an accuracy of 31.90324834519256
#  For Lasso Regression Algorithm, we had an accuracy of 31.882472664464178
#  For Bayesian Algorithm, we had an accuracy of 31.91763685260698
#  For ARDRegression Algorithm, we had an accuracy of 31.753150178931
#  For Lars Algorithm, we had an accuracy of 20.86464461746277
#  For  Orthogonal Matching Pursuit Algorithm, we had an accuracy of 31.740937036619933
#  For Passive Aggression Regressor Algorithm, we had an accuracy of 31.396784462237825
#  For Decision TreeRegressor Algorithm, we had an accuracy of 30.104076511116485
#  For Random Forest Regressor Algorithm, we had an accuracy of 37.442284904879386
#  For Gradient Boost Regressor Algorithm, we had an accuracy of 33.301916656188034
#  For Hist Regressor Algorithm, we had an accuracy of 40.420003536632244
# ...

# %% [markdown]
# # NEW

# %%
import catboost
from catboost import CatBoostRegressor
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train=standard.fit_transform(x_train) 
x_test=standard.transform(x_test)
model = CatBoostRegressor(iterations=10000,  # Number of boosting iterations
                         learning_rate=0.1,  # Step size shrinking to prevent overfitting
                         depth=9,  # Depth of the decision tree
                         loss_function='RMSE')  # Regression loss function

model.fit(x_train, y_train)


y_pred = model.predict(x_test)
score=model.score(x_test,y_test)
plt.figure(figsize=(8, 6))
plt.scatter(y_test,y_pred, color='b', label='Predicted vs. Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', linewidth=2, label='Ideal Line')
# Set labels and title
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title("TESTING DATA FOR  FOR Hist CatBoost  Regressor")
plt.legend()
score
# Out:
# 0:	learn: 55762.9061085	total: 163ms	remaining: 27m 8s
# 1:	learn: 53997.6832198	total: 172ms	remaining: 14m 18s
# 2:	learn: 52460.9990258	total: 179ms	remaining: 9m 56s
# 3:	learn: 51243.1742587	total: 181ms	remaining: 7m 33s
# 4:	learn: 50282.8031638	total: 187ms	remaining: 6m 13s
# 5:	learn: 49361.2829497	total: 190ms	remaining: 5m 16s
# 6:	learn: 48531.5404615	total: 195ms	remaining: 4m 37s
# 7:	learn: 47805.5478992	total: 198ms	remaining: 4m 7s
# 8:	learn: 47100.6311916	total: 201ms	remaining: 3m 43s
# 9:	learn: 46586.4632832	total: 204ms	remaining: 3m 23s
# 10:	learn: 46085.3980766	total: 207ms	remaining: 3m 8s
# 11:	learn: 45666.9270965	total: 211ms	remaining: 2m 55s
# 12:	learn: 45353.0192221	total: 213ms	remaining: 2m 43s
# 13:	learn: 44998.9302398	total: 216ms	remaining: 2m 34s
# 14:	learn: 44686.5098469	total: 220ms	remaining: 2m 26s
# 15:	learn: 44431.7066885	total: 224ms	remaining: 2m 20s
# 16:	learn: 44202.4322539	total: 229ms	remaining: 2m 14s
# ...
